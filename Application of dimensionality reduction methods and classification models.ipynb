# %% [markdown]
# ____
# __Universite de Technologie de Troyes__<br/>
# __Universidad Tecnologica Nacional Buenos Aires__<br/>
# __Master OSS__<br/>
# __Machine Learning & Pattern Recognition__<br/>
# __Practice Sessions__<br/>
# __Teacher: Martin Palazzo__<br/>
# __Topic: Final Assessment__
# ____

# %%
# basics
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import numpy as np

#Train test
from sklearn.model_selection import train_test_split

#sklearn
from sklearn.model_selection import train_test_split
from sklearn import datasets


#StandarScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

#PCA
from sklearn.decomposition import PCA

#Kernell PCA
from sklearn.decomposition import KernelPCA

#TSNE
from sklearn.manifold import TSNE

#SVM
from sklearn.svm import SVC # "Support vector classifier"
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

#Logistic Regression
from sklearn.linear_model import LogisticRegression


#Grid search
from sklearn.model_selection import GridSearchCV

#Autoencoder
from keras.layers import Input, Dense
from keras.models import Model

#Warnings
import warnings

# %% [markdown]
# # Load dataset

# %%
 warnings.filterwarnings("ignore")

# %%
# about the dataset
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_california_housing.html#sklearn.datasets.fetch_california_housing
data = datasets.load_breast_cancer()

# %%
# get feature matrix and label vector
# get feature matrix
x = data.data
# get label vector
y = data.target

# %%
# visualize the label vector 
sns.countplot(y)
plt.show()

# %%
# get the shape of the X matrix
x.shape
# Out:
# (569, 30)

# %%
#make train-test-split (80% train , 20% test)

xtr, xte, ytr, yte = train_test_split(x,y, test_size = 0.2,random_state=0)

# %%
#Firt, we use standar scaler to optimize the results
#scaler = StandardScaler()
#xtr_sc = scaler.fit_transform(xtr)
#xte_sc = scaler.transform(xte)

scaler = MinMaxScaler()
scaler.fit(xtr)

xtr_sc = scaler.transform(xtr)
xte_sc = scaler.transform(xte)

# %%
f, ax = plt.subplots(1,2)
f.set_size_inches(15,6)

sns.heatmap(xtr,ax=ax[0])
ax[0].set_title('Non-normalized data')
sns.heatmap(xtr_sc,ax=ax[1])
ax[1].set_title('Normalized data')
# Out:
# Text(0.5, 1.0, 'Normalized data')

# %%
# within train set make dimension reduction with PCA and kPCA from D = x.shape[1] features to P = [2,4,6] latent dimensions.
pca_2 = PCA(n_components=2,random_state=0)
pca_2.fit(xtr_sc)
xtr_pca_2 = pca_2.transform(xtr_sc)
xte_pca_2 = pca_2.transform(xte_sc)

pca_4 = PCA(n_components=4,random_state=0)
pca_4.fit(xtr_sc)
xtr_pca_4 = pca_4.transform(xtr_sc)
xte_pca_4 = pca_4.transform(xte_sc)

pca_6 = PCA(n_components=6,random_state=0)
pca_6.fit(xtr_sc)
xtr_pca_6 = pca_6.transform(xtr_sc)
xte_pca_6 = pca_6.transform(xte_sc)


# check the cumulative variance within the preserved components
print(f'• The cumulative variance within the 2 components:  {np.sum(pca_2.explained_variance_ratio_)} \n') 
sns.barplot(np.arange(0,2),pca_2.explained_variance_ratio_)
plt.title('Explained variance per principal component')
plt.show()

print(f'• The cumulative variance within the 4 components:  {np.sum(pca_4.explained_variance_ratio_)} \n') 
sns.barplot(np.arange(0,4),pca_4.explained_variance_ratio_)
plt.title('Explained variance per principal component')
plt.show()

print(f'• The cumulative variance within the 6 components:  {np.sum(pca_6.explained_variance_ratio_)} \n') 
sns.barplot(np.arange(0,6),pca_6.explained_variance_ratio_)
plt.title('Explained variance per principal component')
plt.show()
# Out:
# • The cumulative variance within the 2 components:  0.6827613977344271
# • The cumulative variance within the 4 components:  0.829907311728463
# • The cumulative variance within the 6 components:  0.9089466454147912

# %%
#Make dimension reduction with kPCA

kpca_2 = KernelPCA(n_components=2, kernel='rbf',gamma= 0.05,random_state=0)
kpca_2.fit(xtr_sc)
xtr_kpca_2 = kpca_2.transform(xtr_sc)
xte_kpca_2 = kpca_2.transform(xte_sc)

kpca_4 = KernelPCA(n_components=4, kernel='rbf',gamma= 0.05,random_state=0)
kpca_4.fit(xtr_sc)
xtr_kpca_4 = kpca_4.transform(xtr_sc)
xte_kpca_4 = kpca_4.transform(xte_sc)

kpca_6 = KernelPCA(n_components=6, kernel='rbf',gamma= 0.05,random_state=0)
kpca_6.fit(xtr_sc)
xtr_kpca_6 = kpca_6.transform(xtr_sc)
xte_kpca_6 = kpca_6.transform(xte_sc)

# %%
#Extra: make a reduction with Autoencoder
original_dim=xtr_sc.shape[1]

#latent_dim=2
# define the input layer and the encoding layer
input_layer_2 = Input(shape=(original_dim,))
encoding_layer_2 = Dense(2, activation='relu')(input_layer_2)

# define the decoding layer
decoding_layer_2 = Dense(original_dim, activation='sigmoid')(encoding_layer_2)

# define the autoencoder model
autoencoder_2 = Model(input_layer_2, decoding_layer_2)

# compile the model
autoencoder_2.compile(optimizer='adam', loss='binary_crossentropy')

# fit the model to the data
autoencoder_2.fit(xtr_sc, xtr_sc, epochs=50, batch_size=32, validation_data=(xte_sc, xte_sc))

# get the encoding and decoding layers
encoder_2 = Model(input_layer_2, encoding_layer_2)
decoder_2 = Model(encoding_layer_2, decoding_layer_2)

# reduce the dimensionality of the data using the encoding layer
xlat_tr_2 = encoder_2.predict(xtr)
xlat_te_2 = encoder_2.predict(xte)


#latent_dim=4
# define the input layer and the encoding layer
input_layer_4 = Input(shape=(original_dim,))
encoding_layer_4 = Dense(4, activation='relu')(input_layer_4)

# define the decoding layer
decoding_layer_4 = Dense(original_dim, activation='sigmoid')(encoding_layer_4)

# define the autoencoder model
autoencoder_4 = Model(input_layer_4, decoding_layer_4)

# compile the model
autoencoder_4.compile(optimizer='adam', loss='binary_crossentropy')

# fit the model to the data
autoencoder_4.fit(xtr_sc, xtr_sc, epochs=50, batch_size=32, validation_data=(xte_sc, xte_sc))

# get the encoding and decoding layers
encoder_4 = Model(input_layer_4, encoding_layer_4)
decoder_4 = Model(encoding_layer_4, decoding_layer_4)

# reduce the dimensionality of the data using the encoding layer
xlat_tr_4 = encoder_4.predict(xtr)
xlat_te_4 = encoder_4.predict(xte)

#latent_dim=6
# define the input layer and the encoding layer
input_layer_6 = Input(shape=(original_dim,))
encoding_layer_6 = Dense(6, activation='relu')(input_layer_6)

# define the decoding layer
decoding_layer_6 = Dense(original_dim, activation='sigmoid')(encoding_layer_6)

# define the autoencoder model
autoencoder_6 = Model(input_layer_6, decoding_layer_6)

# compile the model
autoencoder_6.compile(optimizer='adam', loss='binary_crossentropy')

# fit the model to the data
autoencoder_6.fit(xtr_sc, xtr_sc, epochs=50, batch_size=32, validation_data=(xte_sc, xte_sc))

# get the encoding and decoding layers
encoder_6 = Model(input_layer_6, encoding_layer_6)
decoder_6 = Model(encoding_layer_6, decoding_layer_6)

# reduce the dimensionality of the data using the encoding layer
xlat_tr_6 = encoder_6.predict(xtr)
xlat_te_6 = encoder_6.predict(xte)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 30ms/step - loss: 0.7045 - val_loss: 0.6997
# Epoch 2/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6961 - val_loss: 0.6923
# Epoch 3/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6893 - val_loss: 0.6863
# Epoch 4/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6837 - val_loss: 0.6814
# Epoch 5/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6790 - val_loss: 0.6772
# Epoch 6/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6748 - val_loss: 0.6734
# Epoch 7/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6711 - val_loss: 0.6700
# Epoch 8/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6676 - val_loss: 0.6667
# Epoch 9/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6643 - val_loss: 0.6636
# Epoch 10/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6611 - val_loss: 0.6605
# Epoch 11/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6580 - val_loss: 0.6576
# Epoch 12/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6549 - val_loss: 0.6547
# Epoch 13/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6519 - val_loss: 0.6518
# Epoch 14/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6489 - val_loss: 0.6489
# Epoch 15/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6459 - val_loss: 0.6461
# Epoch 16/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6429 - val_loss: 0.6431
# Epoch 17/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6398 - val_loss: 0.6401
# Epoch 18/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6365 - val_loss: 0.6370
# Epoch 19/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6330 - val_loss: 0.6336
# Epoch 20/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6292 - val_loss: 0.6299
# Epoch 21/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6251 - val_loss: 0.6257
# Epoch 22/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6205 - val_loss: 0.6212
# Epoch 23/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6154 - val_loss: 0.6163
# Epoch 24/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6100 - val_loss: 0.6112
# Epoch 25/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6045 - val_loss: 0.6061
# Epoch 26/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5988 - val_loss: 0.6010
# Epoch 27/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5934 - val_loss: 0.5962
# Epoch 28/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5883 - val_loss: 0.5917
# Epoch 29/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5834 - val_loss: 0.5875
# Epoch 30/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5789 - val_loss: 0.5836
# Epoch 31/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5748 - val_loss: 0.5801
# Epoch 32/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5710 - val_loss: 0.5769
# Epoch 33/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5676 - val_loss: 0.5739
# Epoch 34/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5645 - val_loss: 0.5713
# Epoch 35/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5618 - val_loss: 0.5688
# Epoch 36/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5593 - val_loss: 0.5666
# Epoch 37/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5570 - val_loss: 0.5646
# Epoch 38/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5550 - val_loss: 0.5629
# Epoch 39/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5532 - val_loss: 0.5613
# Epoch 40/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5515 - val_loss: 0.5598
# Epoch 41/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5500 - val_loss: 0.5585
# Epoch 42/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5487 - val_loss: 0.5573
# Epoch 43/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5475 - val_loss: 0.5562
# Epoch 44/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5463 - val_loss: 0.5552
# Epoch 45/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5453 - val_loss: 0.5542
# Epoch 46/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5443 - val_loss: 0.5533
# Epoch 47/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5435 - val_loss: 0.5525
# Epoch 48/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5426 - val_loss: 0.5518
# Epoch 49/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5418 - val_loss: 0.5511
# Epoch 50/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5411 - val_loss: 0.5503
# 15/15 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# Epoch 1/50
# 15/15 [==============================] - 1s 22ms/step - loss: 0.6938 - val_loss: 0.6906
# Epoch 2/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6883 - val_loss: 0.6863
# Epoch 3/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6843 - val_loss: 0.6826
# Epoch 4/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6806 - val_loss: 0.6791
# Epoch 5/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6770 - val_loss: 0.6757
# Epoch 6/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6735 - val_loss: 0.6724
# Epoch 7/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6700 - val_loss: 0.6691
# Epoch 8/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6666 - val_loss: 0.6657
# Epoch 9/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6630 - val_loss: 0.6623
# Epoch 10/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6594 - val_loss: 0.6588
# Epoch 11/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6554 - val_loss: 0.6548
# Epoch 12/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6508 - val_loss: 0.6500
# Epoch 13/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6450 - val_loss: 0.6440
# Epoch 14/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6378 - val_loss: 0.6368
# Epoch 15/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6292 - val_loss: 0.6288
# Epoch 16/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6201 - val_loss: 0.6206
# Epoch 17/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6113 - val_loss: 0.6130
# Epoch 18/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6030 - val_loss: 0.6060
# Epoch 19/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5955 - val_loss: 0.5998
# Epoch 20/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5889 - val_loss: 0.5943
# Epoch 21/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5831 - val_loss: 0.5895
# Epoch 22/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5781 - val_loss: 0.5853
# Epoch 23/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5739 - val_loss: 0.5818
# Epoch 24/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5704 - val_loss: 0.5787
# Epoch 25/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5672 - val_loss: 0.5761
# Epoch 26/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5646 - val_loss: 0.5738
# Epoch 27/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5622 - val_loss: 0.5717
# Epoch 28/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5603 - val_loss: 0.5700
# Epoch 29/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5584 - val_loss: 0.5684
# Epoch 30/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5569 - val_loss: 0.5668
# Epoch 31/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5556 - val_loss: 0.5655
# Epoch 32/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5542 - val_loss: 0.5643
# Epoch 33/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5531 - val_loss: 0.5631
# Epoch 34/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5521 - val_loss: 0.5621
# Epoch 35/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5511 - val_loss: 0.5612
# Epoch 36/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5502 - val_loss: 0.5603
# Epoch 37/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5494 - val_loss: 0.5596
# Epoch 38/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5485 - val_loss: 0.5588
# Epoch 39/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5477 - val_loss: 0.5580
# Epoch 40/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5470 - val_loss: 0.5572
# Epoch 41/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5463 - val_loss: 0.5565
# Epoch 42/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5456 - val_loss: 0.5559
# Epoch 43/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5450 - val_loss: 0.5552
# Epoch 44/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5444 - val_loss: 0.5546
# Epoch 45/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5438 - val_loss: 0.5541
# Epoch 46/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5432 - val_loss: 0.5535
# Epoch 47/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5426 - val_loss: 0.5529
# Epoch 48/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5420 - val_loss: 0.5523
# Epoch 49/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5415 - val_loss: 0.5517
# Epoch 50/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5409 - val_loss: 0.5511
# 15/15 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# Epoch 1/50
# 15/15 [==============================] - 1s 25ms/step - loss: 0.6898 - val_loss: 0.6862
# Epoch 2/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6827 - val_loss: 0.6793
# Epoch 3/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6754 - val_loss: 0.6719
# Epoch 4/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6672 - val_loss: 0.6639
# Epoch 5/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6584 - val_loss: 0.6552
# Epoch 6/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6490 - val_loss: 0.6464
# Epoch 7/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6394 - val_loss: 0.6374
# Epoch 8/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6296 - val_loss: 0.6281
# Epoch 9/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6197 - val_loss: 0.6191
# Epoch 10/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6100 - val_loss: 0.6103
# Epoch 11/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6008 - val_loss: 0.6021
# Epoch 12/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5924 - val_loss: 0.5946
# Epoch 13/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5846 - val_loss: 0.5879
# Epoch 14/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5780 - val_loss: 0.5820
# Epoch 15/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5718 - val_loss: 0.5766
# Epoch 16/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5664 - val_loss: 0.5720
# Epoch 17/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5617 - val_loss: 0.5678
# Epoch 18/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5575 - val_loss: 0.5640
# Epoch 19/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5534 - val_loss: 0.5601
# Epoch 20/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5494 - val_loss: 0.5563
# Epoch 21/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5455 - val_loss: 0.5525
# Epoch 22/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5418 - val_loss: 0.5490
# Epoch 23/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5384 - val_loss: 0.5459
# Epoch 24/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5352 - val_loss: 0.5431
# Epoch 25/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5324 - val_loss: 0.5406
# Epoch 26/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.5299 - val_loss: 0.5379
# Epoch 27/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5276 - val_loss: 0.5360
# Epoch 28/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5256 - val_loss: 0.5340
# Epoch 29/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5237 - val_loss: 0.5321
# Epoch 30/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5220 - val_loss: 0.5304
# Epoch 31/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5204 - val_loss: 0.5288
# Epoch 32/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5190 - val_loss: 0.5275
# Epoch 33/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5177 - val_loss: 0.5263
# Epoch 34/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5164 - val_loss: 0.5253
# Epoch 35/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5153 - val_loss: 0.5240
# Epoch 36/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5143 - val_loss: 0.5228
# Epoch 37/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5133 - val_loss: 0.5220
# Epoch 38/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5125 - val_loss: 0.5211
# Epoch 39/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5116 - val_loss: 0.5203
# Epoch 40/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5109 - val_loss: 0.5196
# Epoch 41/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5102 - val_loss: 0.5189
# Epoch 42/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5095 - val_loss: 0.5180
# Epoch 43/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5089 - val_loss: 0.5175
# Epoch 44/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5083 - val_loss: 0.5169
# Epoch 45/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5078 - val_loss: 0.5163
# Epoch 46/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5072 - val_loss: 0.5157
# Epoch 47/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5067 - val_loss: 0.5152
# Epoch 48/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5062 - val_loss: 0.5149
# Epoch 49/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5057 - val_loss: 0.5143
# Epoch 50/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5053 - val_loss: 0.5138
# 15/15 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 5ms/step

# %%
#Before evisualization, use TSNE tool for xtr_pca and xtr_kpca
#As the method TSNE has a cost function that is not convex, i.e. with different initializations we can get different results.


xtr_kpca_tsne = TSNE(n_components=2,random_state=0).fit_transform(xtr_kpca_2)
xtr_pca_tsne = TSNE(n_components=2,random_state=0).fit_transform(xtr_pca_2)
xtr_ae_tsne = TSNE(n_components=2,random_state=0).fit_transform(xlat_tr_2)

# %%
#Visualize the reduced subspace in 2 dimensions and colour the samples with the labels, one visualization for PCA and one for kPCA

#Visualization for PCA and kPCA
f, ax = plt.subplots(1,3)
f.set_size_inches(15,6)

sns.scatterplot(x = xtr_pca_tsne[(ytr).ravel() == 0,0], y = xtr_pca_tsne[ytr.ravel() == 0,1], ax= ax[0], legend='full', label = '0')
sns.scatterplot(x = xtr_pca_tsne[ytr.ravel() == 1,0], y = xtr_pca_tsne[ytr.ravel() == 1,1], ax= ax[0], legend='full', label = '1')
ax[0].set_title("PCA")
sns.scatterplot(x = xtr_kpca_tsne[(ytr).ravel() == 0,0], y = xtr_kpca_tsne[ytr.ravel() == 0,1], ax= ax[1], legend='full', label = '0')
sns.scatterplot(x = xtr_kpca_tsne[ytr.ravel() == 1,0], y = xtr_kpca_tsne[ytr.ravel() == 1,1], ax= ax[1], legend='full', label = '1')
ax[1].set_title("KPCA")
sns.scatterplot(x = xtr_ae_tsne[(ytr).ravel() == 0,0], y = xtr_ae_tsne[ytr.ravel() == 0,1], ax= ax[2], legend='full', label = '0')
sns.scatterplot(x = xtr_ae_tsne[ytr.ravel() == 1,0], y = xtr_ae_tsne[ytr.ravel() == 1,1], ax= ax[2], legend='full', label = '1')
ax[2].set_title("AUTOENCODER")

plt.show()

# %%
# Create a vector with the results
results_df = pd.DataFrame(columns=['Model','Dimensionality reduction','Components','Accuracy'])

# %%
#within train set perform classification with SVM and Logistic Regression (check scikit learn toolkit). 
#Select the best hyperparameters of the models by using cross-validation (check GridSearchCV method on scikit learn).

#SVC

param_grid = {'C':  np.logspace(-4, 4, 10),
              'kernel': ['linear', 'rbf'],
              'gamma' :np.logspace(-4, 4, 10)}
svc = SVC(random_state=0)
grid_search_svc = GridSearchCV(svc, param_grid, cv=5, scoring='accuracy')

# Fit the grid search object to the data
grid_search_svc.fit(xtr_sc, ytr)

print(f"Best hyperparameters: {grid_search_svc.best_params_}")

# Get the best model
best_model_svc = grid_search_svc.best_estimator_

# Apply the best model to the test data
y_pred_svc = best_model_svc.predict(xte_sc)

# Calculate the accuracy of the predictions
accuracy_svc = best_model_svc.score(xte_sc, yte)
print(f"Test accuracy: {accuracy_svc:.3f}")
# Out:
# Best hyperparameters: {'C': 2.782559402207126, 'gamma': 0.3593813663804626, 'kernel': 'rbf'}
# Test accuracy: 0.965

# %%
#Save result
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':None,
                               'Components':None,
                               'Accuracy': accuracy_svc},ignore_index=True)

# %%
#LR

# Define the hyperparameter grid
param_grid = {'C': np.logspace(-4, 4, 10),
 'penalty': ['l1', 'l2'],
 'solver' :['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']}

# Initialize the logistic regression model
lr = LogisticRegression(random_state=0)

# Initialize the grid search object
grid_search_lr = GridSearchCV(lr, param_grid, cv=5, scoring='accuracy')

# Fit the grid search object to the data
grid_search_lr.fit(xtr_sc, ytr)
# Print the best hyperparameters
print(f"Best hyperparameters: {grid_search_lr.best_params_}")

# Get the best model
best_model_lr = grid_search_lr.best_estimator_

# Apply the best model to the test data
y_pred_lr = best_model_lr.predict(xte_sc)

# Calculate the accuracy of the predictions
accuracy_lr = best_model_lr.score(xte_sc, yte)
print(f"Test accuracy: {accuracy_lr:.3f}")
# Out:
# Best hyperparameters: {'C': 21.54434690031882, 'penalty': 'l1', 'solver': 'saga'}
# Test accuracy: 0.965

# %%
#Save result
results_df = results_df.append({'Model':'Logistic Regression with CV',
                               'Dimensionality reduction':None,
                               'Components':None,
                               'Accuracy': accuracy_lr},ignore_index=True)

# %%
#Transform the test set with the dimension reduction learned in the first step. 
#Then apply the learned classification function of the previous step. 

    
#svc with pca 
svc2=best_model_svc
svc2.fit(xtr_pca_2, ytr)
pred_svc2_pca_2 = svc2.predict(xte_pca_2)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'PCA',
                               'Components':2,
                               'Accuracy': accuracy_score(yte, pred_svc2_pca_2)
                               },ignore_index=True)

svc2=best_model_svc
svc2.fit(xtr_pca_4, ytr)
pred_svc2_pca_4 = svc2.predict(xte_pca_4)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'PCA',
                               'Components':4,
                               'Accuracy': accuracy_score(yte, pred_svc2_pca_4)
                               },ignore_index=True)

svc2=best_model_svc
svc2.fit(xtr_pca_6, ytr)
pred_svc2_pca_6 = svc2.predict(xte_pca_6)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'PCA',
                               'Components':6,
                               'Accuracy': accuracy_score(yte, pred_svc2_pca_6)
                            
                               },ignore_index=True)


#svc with kpca 

svc2=best_model_svc   
svc2.fit(xtr_kpca_2, ytr)
pred_svc2_kpca_2 = svc2.predict(xte_kpca_2)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'KPCA',
                               'Components':2,
                               'Accuracy': accuracy_score(yte, pred_svc2_kpca_2)
                               },ignore_index=True)
svc2=best_model_svc
svc2.fit(xtr_kpca_4, ytr)
pred_svc2_pca_4 = svc2.predict(xte_pca_4)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'KPCA',
                               'Components':4,
                               'Accuracy': accuracy_score(yte, pred_svc2_pca_4)
                               },ignore_index=True)
svc2=best_model_svc
svc2.fit(xtr_pca_6, ytr)
pred_svc2_pca_6 = svc2.predict(xte_pca_6)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'KPCA',
                               'Components':6,
                               'Accuracy': accuracy_score(yte, pred_svc2_pca_6)
                               },ignore_index=True)


#svc with Autoencoder 

svc2=best_model_svc   
svc2.fit(xlat_tr_2, ytr)
pred_svc2_ae_2 = svc2.predict(xlat_te_2)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'Autoencoder',
                               'Components':2,
                               'Accuracy': accuracy_score(yte, pred_svc2_ae_2)
                               },ignore_index=True)
svc2=best_model_svc
svc2.fit(xlat_tr_4, ytr)
pred_svc2_ae_4 = svc2.predict(xlat_te_4)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'Autoencoder',
                               'Components':4,
                               'Accuracy': accuracy_score(yte, pred_svc2_ae_4)
                               },ignore_index=True)
svc2=best_model_svc
svc2.fit(xlat_tr_6, ytr)
pred_svc2_ae_6 = svc2.predict(xlat_te_6)
results_df = results_df.append({'Model':'SVM with CV',
                               'Dimensionality reduction':'Autoencoder',
                               'Components':6,
                               'Accuracy': accuracy_score(yte, pred_svc2_ae_6)
                               },ignore_index=True)

# %%
#Transform the test set with the dimension reduction learned in the first step. 
#Then apply the learned classification function of the previous step. 

    
#lr with pca 
lr2=best_model_lr
lr2.fit(xtr_pca_2, ytr)
pred_lr2_pca_2 = lr2.predict(xte_pca_2)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'PCA',
                               'Components':2,
                               'Accuracy': lr2.score(xte_pca_2, yte)
                               },ignore_index=True)
lr2=best_model_lr
lr2.fit(xtr_pca_4, ytr)
pred_lr2_pca_4 = lr2.predict(xte_pca_4)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'PCA',
                               'Components':4,
                               'Accuracy': lr2.score(xte_pca_4, yte)
                               },ignore_index=True)

lr2=best_model_lr
lr2.fit(xtr_pca_6, ytr)
pred_lr2_pca_6 = lr2.predict(xte_pca_6)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'PCA',
                               'Components':6,
                               'Accuracy': lr2.score(xte_pca_6, yte)
                               },ignore_index=True)



#LR with kpca 
lr2=best_model_lr
lr2.fit(xtr_kpca_2, ytr)
pred_lr2_kpca_2 = lr2.predict(xte_kpca_2)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'KPCA',
                               'Components':2,
                               'Accuracy': lr2.score(xte_kpca_2, yte),
                               },ignore_index=True)
lr2=best_model_lr
lr2.fit(xtr_kpca_4, ytr)
pred_lr2_kpca_4 = lr2.predict(xte_kpca_4)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'KPCA',
                               'Components':4,
                               'Accuracy': lr2.score(xte_kpca_4, yte),
                               },ignore_index=True)
lr2=best_model_lr
lr2.fit(xtr_kpca_6, ytr)
pred_lr2_kpca_6 = lr2.predict(xte_kpca_6)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'KPCA',
                               'Components':6,
                               'Accuracy': lr2.score(xte_kpca_6, yte)
                               },ignore_index=True)



#LR with Autoencoder 
lr2=best_model_lr
lr2.fit(xlat_tr_2, ytr)
pred_lr2_ae_2 = lr2.predict(xlat_te_2)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'Autoencoder',
                               'Components':2,
                               'Accuracy': lr2.score(xlat_te_2, yte),
                               },ignore_index=True)
lr2=best_model_lr
lr2.fit(xlat_tr_4, ytr)
pred_lr2_ae_4 = lr2.predict(xlat_te_4)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'Autoencoder',
                               'Components':4,
                               'Accuracy': lr2.score(xlat_te_4, yte),
                               },ignore_index=True)
lr2=best_model_lr
lr2.fit(xlat_tr_6, ytr)
pred_lr2_ae_6 = lr2.predict(xlat_te_6)
results_df = results_df.append({'Model':'Logistic regression with CV',
                               'Dimensionality reduction':'Autoencoder',
                               'Components':6,
                               'Accuracy': lr2.score(xlat_te_6, yte)
                  
                               },ignore_index=True)

# %%
#Determine which model is the best based on evaluation metrics.
results_df.sort_values(by= 'Accuracy' ,ascending= False)
# Out:
#                           Model Dimensionality reduction Components  Accuracy
# 10  Logistic regression with CV                      PCA          6  0.973684
# 13  Logistic regression with CV                     KPCA          6  0.973684
# 7                   SVM with CV                     KPCA          6  0.964912
# 1   Logistic Regression with CV                     None       None  0.964912
# 0                   SVM with CV                     None       None  0.964912
# 4                   SVM with CV                      PCA          6  0.964912
# 5                   SVM with CV                     KPCA          2  0.956140
# 9   Logistic regression with CV                      PCA          4  0.956140
# 12  Logistic regression with CV                     KPCA          4  0.956140
# 3                   SVM with CV                      PCA          4  0.947368
# 6                   SVM with CV                     KPCA          4  0.929825
# 8   Logistic regression with CV                      PCA          2  0.929825
# 11  Logistic regression with CV                     KPCA          2  0.929825
# 2                   SVM with CV                      PCA          2  0.921053
# 15  Logistic regression with CV              Autoencoder          4  0.894737
# 16  Logistic regression with CV              Autoencoder          6  0.894737
# 17                  SVM with CV              Autoencoder          2  0.868421
# 19                  SVM with CV              Autoencoder          6  0.596491
# 18                  SVM with CV              Autoencoder          4  0.587719
# 14  Logistic regression with CV              Autoencoder          2  0.412281

# %% [markdown]
# # **Conditions**
# - the assignment is individual and personal. Each student must do it by their own.
# - The methodology and results obtained must be written in a 2-3 pages report.
# #### **The report must include**
# - at least 3 cited papers.
# - the following sections: Title, Abstract, Introduccion, Methods, Experiments, Discussion and Conclusions
# - You are free to implement more methods like Neural Networks

# %% [markdown]
# # **Objectives for the assignment**
# - make train-test-split (80% train , 20% test)
# - within train set make dimension reduction with PCA and kPCA from D = x.shape[1] features to P = [2,4,6] latent dimensions.
# - Visualize the reduced subspace in 2 dimensions and colour the samples with the labels, one visualization for PCA and one for kPCA.
# - within train set perform classification with SVM and Logistic Regression (check scikit learn toolkit). Select the best hyperparameters of the models by using cross-validation (check GridSearchCV method on scikit learn).
# - Transform the test set with the dimension reduction learned in the first step. Then apply the learned classification function of the previous step. Determine which model is the best based on evaluation metrics.
# - compare the results of classification in latent space against the same classification in the original input space to measure if the latent space improves the classification task.
